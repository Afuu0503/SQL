# %% [markdown]
# # Welcome in first exercise!
# ## 1. Firstly let's import libraries

# %%
import pandas as pd
df = pd.read_csv("train.csv")
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %% [markdown]
# ## 2. Let's hange the names of the columns

# %%
df.rename(columns = {'Row ID':'row_id'}, inplace = True)
df.rename(columns = {'Order ID':'order_id'}, inplace = True)
df.rename(columns = {'Order Date':'order_date'}, inplace = True)
df.rename(columns = {'Ship Date':'ship_date'}, inplace = True)
df.rename(columns = {'Ship Mode':'ship_mode'}, inplace = True)
df.rename(columns = {'Customer ID':'customer_id'}, inplace = True)
df.rename(columns = {'Customer Name':'customer_name'}, inplace = True)
df.rename(columns = {'Segment':'segment'}, inplace = True)
df.rename(columns = {'Country':'country'}, inplace = True)
df.rename(columns = {'City':'city'}, inplace = True)
df.rename(columns = {'State':'state'}, inplace = True)
df.rename(columns = {'Postal Code':'postal_code'}, inplace = True)
df.rename(columns = {'Region':'region'}, inplace = True)
df.rename(columns = {'Product ID':'product_id'}, inplace = True)
df.rename(columns = {'Category':'category'}, inplace = True)
df.rename(columns = {'Sub-Category':'sub_category'}, inplace = True)
df.rename(columns = {'Product Name':'product_name'}, inplace = True)
df.rename(columns = {'Sales':'sales'}, inplace = True)

# %%
df
# Out:
#       row_id        order_id  order_date   ship_date       ship_mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      customer_id     customer_name    segment        country             city  \
# ...

# %% [markdown]
# ## 3. We need to see our Data Types if they're correct

# %%
df.dtypes
# Out:
# row_id             int64
# order_id          object
# order_date        object
# ship_date         object
# ship_mode         object
# customer_id       object
# customer_name     object
# segment           object
# country           object
# city              object
# state             object
# postal_code      float64
# region            object
# product_id        object
# category          object
# sub_category      object
# product_name      object
# sales            float64
# dtype: object

# %% [markdown]
# **In order_date and ship_date we've got date data type, but we're going to change that in SQL query.**
# ## 4. Now we will check if ther're any NULL/NaN row

# %%
df.isnull().sum()
# Out:
# row_id            0
# order_id          0
# order_date        0
# ship_date         0
# ship_mode         0
# customer_id       0
# customer_name     0
# segment           0
# country           0
# city              0
# state             0
# postal_code      11
# region            0
# product_id        0
# category          0
# sub_category      0
# product_name      0
# sales             0
# dtype: int64

# %% [markdown]
# **We can see some results in postal_code column. I want to check where it is!**

# %%
df[df['postal_code'].isnull()]
# Out:
#       row_id        order_id  order_date   ship_date       ship_mode  \
# 2234    2235  CA-2018-104066  05/12/2018  10/12/2018  Standard Class
# 5274    5275  CA-2016-162887  07/11/2016  09/11/2016    Second Class
# 8798    8799  US-2017-150140  06/04/2017  10/04/2017  Standard Class
# 9146    9147  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9147    9148  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9148    9149  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9386    9387  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9387    9388  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9388    9389  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9389    9390  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9741    9742  CA-2016-117086  08/11/2016  12/11/2016  Standard Class
#
#      customer_id     customer_name      segment        country        city  \
# ...

# %% [markdown]
# **Hmmmm? Should we delete them? Or should we put into "Burlington" value actual postal_code manually?** </br>
# ![image.png](attachment:a6f3b5e6-5361-4edc-99ae-bc0a5d796f86.png)</br>
# All Burlington are from East - that's perfect!

# %%
# we need to create float value, because we want to insert it into floats. df['postal_code'].fillna('05401.0', inplace=True) will only fill the NaN values with object. 
fill_value = 5401.0
df['postal_code'].fillna(fill_value, inplace=True)
df['postal_code'] = df['postal_code'].astype(float)

# %%
df.isnull().sum()
# Out:
# row_id           0
# order_id         0
# order_date       0
# ship_date        0
# ship_mode        0
# customer_id      0
# customer_name    0
# segment          0
# country          0
# city             0
# state            0
# postal_code      0
# region           0
# product_id       0
# category         0
# sub_category     0
# product_name     0
# sales            0
# dtype: int64

# %% [markdown]
# There's no results in postal_code column! Perfect! But, let's see how the data look like

# %%
df.loc[df['postal_code'] == 5401.0]
# Out:
#       row_id        order_id  order_date   ship_date       ship_mode  \
# 2234    2235  CA-2018-104066  05/12/2018  10/12/2018  Standard Class
# 5274    5275  CA-2016-162887  07/11/2016  09/11/2016    Second Class
# 8798    8799  US-2017-150140  06/04/2017  10/04/2017  Standard Class
# 9146    9147  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9147    9148  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9148    9149  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9386    9387  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9387    9388  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9388    9389  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9389    9390  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9741    9742  CA-2016-117086  08/11/2016  12/11/2016  Standard Class
#
#      customer_id     customer_name      segment        country        city  \
# ...

# %% [markdown]
# **As we can see, ther's no NaN values in the "Burlington" row**

# %% [markdown]
# ## 5. We need to save this data as a .parquet file to inport it to the query in Azure Data Studio

# %%
df.to_parquet('train.parquet')

# %%
from viadot.tasks import AzureDataLakeUpload

flow = AzureDataLakeUpload(
                           from_path=f'train.parquet',
                           to_path = 'raw/sap/dzar_data/train.parquet', #If you don't have your file on Data Lake create it in Microsoft Azure Storage Explorer or create it automatically here 
                           overwrite = True
)
flow.run(sp_credentials_secret="App-Azure-CR-DatalakeGen2-AIA")
# Out:
# [2023-09-12 08:29:49+0000] INFO - prefect.adls_upload | Uploading data from train.parquet to azuwevelcedls01p/raw/sap/dzar_data/train.parquet...
# [2023-09-12 08:29:50+0000] INFO - prefect.adls_upload | Successfully uploaded data to azuwevelcedls01p/raw/sap/dzar_data/train.parquet.

# %% [markdown]
# **We need to see what types of data we've got. Here it is a pattern ready to use!**

# %%
def get_df_varchars(df: pd.DataFrame, excess:int=2):
    """Using maximum lengh of data in columns, function genreates varchar dtypes dictionary."""
    max_length_object_cols = {col: df.loc[:, col].astype(str).apply(len).max() for col in df.columns}
    for x in max_length_object_cols:
        maximum = int(max_length_object_cols[x])
        val = (2 * round(maximum/2)) * excess
        if val < 10:
            val = 10
        max_length_object_cols[x] = f'varchar({val})'
    return max_length_object_cols

get_df_varchars(df)
# Out:
# {'row_id': 'varchar(10)',
#  'order_id': 'varchar(28)',
#  'order_date': 'varchar(20)',
#  'ship_date': 'varchar(20)',
#  'ship_mode': 'varchar(28)',
#  'customer_id': 'varchar(16)',
#  'customer_name': 'varchar(44)',
#  'segment': 'varchar(24)',
#  'country': 'varchar(24)',
#  'city': 'varchar(32)',
#  'state': 'varchar(40)',
#  'postal_code': 'varchar(16)',
#  'region': 'varchar(16)',
#  'product_id': 'varchar(32)',
#  'category': 'varchar(32)',
#  'sub_category': 'varchar(24)',
#  'product_name': 'varchar(256)',
#  'sales': 'varchar(16)'}

# %%
from viadot.flows import ADLSToAzureSQL
from prefect.storage import Git
from prefect.run_configs import DockerRun
import pandas as pd
from datetime import date, timedelta
from dateutil.relativedelta import relativedelta
pd.options.display.max_columns = 300
from prefect.schedules import Schedule
from prefect.schedules.clocks import CronClock
from prefect.utilities.notifications import slack_notifier
from prefect.engine.state import Failed


schedule = Schedule(clocks=[CronClock("45 4 * * *")])
slack_handler = slack_notifier(only_states=[Failed])

STORAGE = Git(
    flow_path="flows/prod/raw/afs/cee_afs_pl_daily_to_sql.py",
    repo="",
    git_clone_url_secret_name="data_flows_repo_url"
)

RUN_CONFIG = DockerRun(
    image="docker.pkg.github.com/dyvenia/viadot/viadot:latest",
    labels=["prod"],)

credentials_secret = "azuwevelcesql-p-001" #this is our server
sp_credentials_secret="App-Azure-CR-DatalakeGen2-AIA"

flow = ADLSToAzureSQL(
        f"1-raw train_daria", #name of your table in Azure Data Studio
        check_col_order = False,
        adls_path = f'raw/sap/dzar_data/train.parquet', #this is patch a from your data lake file in Azure Storage Explorer where your table was saved  
        schema = 'raw', 
        table = f'train_daria', #table name 
        if_exists="replace", 
        write_sep='\t',
        read_sep=',',
        adls_sp_credentials_secret="App-Azure-CR-DatalakeGen2-AIA",
        sqldb_credentials_secret="azuwevelcesql-p-001",
        dtypes={'row_id': 'varchar(10)', #here you need to put varchars from above code. Just copy and past the results :p
             'order_id': 'varchar(28)',
             'order_date': 'varchar(20)',
             'ship_date': 'varchar(20)',
             'ship_mode': 'varchar(28)',
             'customer_id': 'varchar(16)',
             'customer_name': 'varchar(44)',
             'segment': 'varchar(24)',
             'country': 'varchar(24)',
             'city': 'varchar(32)',
             'state': 'varchar(40)',
             'postal_code': 'varchar(16)',
             'region': 'varchar(16)',
             'product_id': 'varchar(32)',
             'category': 'varchar(32)',
             'sub_category': 'varchar(24)',
             'product_name': 'varchar(256)',
             'sales': 'varchar(16)'},
        # schedule=schedule,
        # storage=STORAGE,
        # run_config=RUN_CONFIG,
        # state_handlers=[slack_handler],
        # on_bcp_error = "fail",
)

# flow.register(project_name="cic")
flow.run()
# Out:
# [2023-09-12 11:37:20+0000] WARNING - prefect.Git | Git storage initialized with a `git_clone_url_secret_name`. The value of this Secret will be used to clone the repository, ignoring `repo`, `repo_host`, `git_token_secret_name`,  `git_token_username`, `use_ssh`, and `format_access_token`.
# [2023-09-12 11:37:20+0000] INFO - prefect.FlowRunner | Beginning Flow run for '1-raw train_daria'
# [2023-09-12 11:37:20+0000] INFO - prefect.TaskRunner | Task 'adls_to_df': Starting task run...
# [2023-09-12 11:37:22+0000] INFO - prefect.adls_to_df | Downloading data from azuwevelcedls01p/raw/sap/dzar_data/train.parquet to a DataFrame...
# [2023-09-12 11:37:23+0000] INFO - prefect.adls_to_df | Successfully loaded data.
# [2023-09-12 11:37:24+0000] INFO - prefect.TaskRunner | Task 'adls_to_df': Finished task run for task with final state: 'Success'
# [2023-09-12 11:37:24+0000] INFO - prefect.TaskRunner | Task 'check_dtypes_sort': Starting task run...
# ...

# %% [markdown]
# ## And that's all! Now You can go to Azure Data studio :D
